# %% [markdown]
# # **FINE TUNING WITH LAST BLOCK UNFREEZED**
#
# In this paper we are going to perform the fine tuning by unfreezing the last block of our network and by using early stopping.

# %% [markdown]
# ## **Mount and unzipping**
#
# At the beginning we allow the access to our Google Drive and then we unzip the dataset on our folder.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
'''
# Unzipping dataset
# %cd '/content/gdrive/MyDrive/progetto/dbs/' 
# !unzip -q original_facial_expression.zip
'''
# Out:
# "\n# Unzipping dataset\n%cd '/content/gdrive/MyDrive/progetto/dbs/' \n!unzip -q original_facial_expression.zip\n"

# %% [markdown]
# Now we import all the needed modules and we define the folders' path that we are going to use.

# %%
import glob
import os
import numpy as np
import PIL
from PIL import ImageDraw, ImageOps, Image

import tensorflow as tf
from tensorflow.keras import layers as L
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.preprocessing.image import load_img
from keras.models import load_model

from IPython.display import display
from tqdm.notebook import tqdm

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.svm import SVC, LinearSVC

np.random.seed(42)
tf.random.set_seed(42)


BASE_DIR = '/content/gdrive/MyDrive/progetto/dbs/facial_expression/dataset'
TRAIN_DATA_DIR = os.path.join(BASE_DIR, 'Training')
TEST_DATA_DIR = os.path.join(BASE_DIR, 'PublicTest')

#TO DO: Define the correct batch size
BATCH_SIZE = 256

device_name = tf.test.gpu_device_name()
print('GPU: ', device_name)
# Out:
# GPU:  /device:GPU:0

# %% [markdown]
# ## **Model loading**
#
# Since our pretrained network doesn't belong to Keras, we are going to load the Inception ResNet v1 in the following way:

# %%
facenet = load_model('/content/gdrive/MyDrive/progetto/modello/keras-facenet/model/facenet_keras.h5')
facenet.load_weights('/content/gdrive/MyDrive/progetto/modello/keras-facenet/weights/facenet_keras_weights.h5')
print("Shape: ",facenet.output_shape)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Shape:  (None, 128)

# %% [markdown]
# ## **Dataset Loading**
#
# We use *image_dataset_from_directory()* provided by Keras to load the image dataset. At the end we perform the *prefetch()* function to improve the performance in dataset loading. Thanks to *prefectch()*, while model is executing the step *s* of the training, input pipeline read data for the step *s+1*. In this way the time needed is `max(training_time, time_to_read_data)` instead of `training_time + time_to_read_data`. By using *tf.data.AUTOTUNE*, the value of the data's batch size is decided automatically at runtime.

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TRAIN_DATA_DIR,
    labels='inferred',
    label_mode='int',
    subset="training",
    validation_split=0.2,
    seed=123,
    image_size=(160, 160),
    batch_size=BATCH_SIZE,
    color_mode='rgb')

valid_dataset = tf.keras.preprocessing.image_dataset_from_directory(
   TRAIN_DATA_DIR,
   labels='inferred',
   label_mode='int',
   subset="validation",
   shuffle=False,
   validation_split=0.2,
   seed=123,
   image_size=(160, 160),
   batch_size=BATCH_SIZE,
   color_mode='rgb')

testing_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TEST_DATA_DIR,
    seed=123,
    labels='inferred',
    label_mode='int',
    shuffle=False,
    image_size=(160, 160),
    batch_size=BATCH_SIZE,
    color_mode='rgb')

train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)
valid_dataset = valid_dataset.prefetch(tf.data.experimental.AUTOTUNE)
testing_dataset = testing_dataset.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Found 28709 files belonging to 7 classes.
# Using 22968 files for training.
# Found 28709 files belonging to 7 classes.
# Using 5741 files for validation.
# Found 3589 files belonging to 7 classes.

# %% [markdown]
# ## **Training**
#
# On the top of the pretrained network, we build our densly connected network. We have a *Flatten layer* that reshape the pretrained network's output. Then, we have two *Dense layers*: the first has 128 hidden layers with **ReLu** activation function while the last one has 7 layers (as the output class we have) with **softmax** activation function. Since we don't want to perform fine-tuning, hence we don't want to recompute the weights of the pretrained network, then we set `trainable = False`.

# %%
facenet.trainable = False
model = Sequential()
model.add(L.Input(shape=(160,160,3)))
model.add(facenet)
model.add(L.Flatten())
model.add(L.Dense(128, activation="relu",name="classifier_hidden"))
model.add(L.Dense(7,activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v1 (Functio (None, 128)               22808144
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# classifier_hidden (Dense)    (None, 128)               16512
# _________________________________________________________________
# dense (Dense)                (None, 7)                 903
# =================================================================
# Total params: 22,825,559
# Trainable params: 17,415
# Non-trainable params: 22,808,144
# _________________________________________________________________

# %% [markdown]
# Since we have many classes and an image belongs only to a specific class, we use the **sparse categorical crossentropy** as loss function. As optimizer, we use **RMSprop** with a very low **learning rate** ($10^{-5}$) and by using 0.6 **momentum**. In this way we do little step but thanks to momentum we can avoid local minima. To avoid the problem of overfitting, we add also the **early stopping** whereby the training will stop when the chosen performance measure stops improving.

# %%
model.compile(loss=tf.keras.losses.sparse_categorical_crossentropy,
              optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-5, momentum=0.6),
              metrics=["acc"])
callbacks = [
    # early stopping
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3),

    # model checkpoints (save the best model)
    tf.keras.callbacks.ModelCheckpoint(
        monitor='val_acc',
        save_best_only=True,
        mode='max',
        filepath='/content/gdrive/MyDrive/progetto/modello/keras-facenet/model/fine_tuning_nuovo.h5'),
]

# %%
history = model.fit(
      train_dataset,
      epochs=50,
      validation_data=valid_dataset,
      callbacks=callbacks,
      use_multiprocessing=True,
      batch_size = BATCH_SIZE
      )
# Out:
# Epoch 1/50
# 90/90 [==============================] - 8922s 90s/step - loss: 1.9136 - acc: 0.2068 - val_loss: 2.0542 - val_acc: 0.0852
# Epoch 2/50
# 90/90 [==============================] - 90s 930ms/step - loss: 1.8552 - acc: 0.2293 - val_loss: 1.9984 - val_acc: 0.0826
# Epoch 3/50
# 90/90 [==============================] - 88s 915ms/step - loss: 1.8325 - acc: 0.2373 - val_loss: 1.9780 - val_acc: 0.0902
# Epoch 4/50
# 90/90 [==============================] - 88s 922ms/step - loss: 1.8198 - acc: 0.2446 - val_loss: 1.9662 - val_acc: 0.0918
# Epoch 5/50
# 90/90 [==============================] - 88s 914ms/step - loss: 1.8116 - acc: 0.2471 - val_loss: 1.9535 - val_acc: 0.1014
# Epoch 6/50
# 90/90 [==============================] - 87s 904ms/step - loss: 1.8039 - acc: 0.2484 - val_loss: 1.9213 - val_acc: 0.1188
# Epoch 7/50
# 90/90 [==============================] - 87s 910ms/step - loss: 1.7916 - acc: 0.2566 - val_loss: 1.9115 - val_acc: 0.1238
# Epoch 8/50
# 90/90 [==============================] - 87s 913ms/step - loss: 1.7917 - acc: 0.2533 - val_loss: 1.9126 - val_acc: 0.1209
# Epoch 9/50
# 90/90 [==============================] - 86s 895ms/step - loss: 1.7873 - acc: 0.2582 - val_loss: 1.8994 - val_acc: 0.1294
# Epoch 10/50
# 90/90 [==============================] - 86s 893ms/step - loss: 1.7855 - acc: 0.2558 - val_loss: 1.8855 - val_acc: 0.1453
# Epoch 11/50
# 90/90 [==============================] - 86s 898ms/step - loss: 1.7782 - acc: 0.2634 - val_loss: 1.8822 - val_acc: 0.1447
# Epoch 12/50
# 90/90 [==============================] - 86s 897ms/step - loss: 1.7754 - acc: 0.2668 - val_loss: 1.8782 - val_acc: 0.1488
# Epoch 13/50
# 90/90 [==============================] - 87s 909ms/step - loss: 1.7739 - acc: 0.2647 - val_loss: 1.8671 - val_acc: 0.1533
# Epoch 14/50
# 90/90 [==============================] - 87s 905ms/step - loss: 1.7747 - acc: 0.2638 - val_loss: 1.8821 - val_acc: 0.1446
# Epoch 15/50
# 90/90 [==============================] - 86s 897ms/step - loss: 1.7672 - acc: 0.2756 - val_loss: 1.8555 - val_acc: 0.1663
# Epoch 16/50
# 90/90 [==============================] - 86s 901ms/step - loss: 1.7637 - acc: 0.2797 - val_loss: 1.8550 - val_acc: 0.1665
# Epoch 17/50
# 90/90 [==============================] - 87s 907ms/step - loss: 1.7655 - acc: 0.2698 - val_loss: 1.8719 - val_acc: 0.1557
# Epoch 18/50
# 90/90 [==============================] - 86s 896ms/step - loss: 1.7639 - acc: 0.2764 - val_loss: 1.8457 - val_acc: 0.1752
# Epoch 19/50
# 90/90 [==============================] - 87s 904ms/step - loss: 1.7556 - acc: 0.2762 - val_loss: 1.8422 - val_acc: 0.1777
# Epoch 20/50
# 90/90 [==============================] - 88s 912ms/step - loss: 1.7591 - acc: 0.2757 - val_loss: 1.8438 - val_acc: 0.1867
# Epoch 21/50
# 90/90 [==============================] - 87s 905ms/step - loss: 1.7579 - acc: 0.2756 - val_loss: 1.8461 - val_acc: 0.1883
# Epoch 22/50
# 90/90 [==============================] - 87s 905ms/step - loss: 1.7585 - acc: 0.2761 - val_loss: 1.8553 - val_acc: 0.1780

# %% [markdown]
# ## **Plot**
# Now we plot the results obtained. We can observe a consistent overfitting and a low accuracy in training results (around 28%) as in testing result (again, around 28%).

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# evaluate the model on the test set with evaluate() ...
test_loss, test_accuracy = model.evaluate(testing_dataset)
test_accuracy
# Out:
# 15/15 [==============================] - 1293s 86s/step - loss: 1.7453 - acc: 0.2806
# 0.280579537153244

# %% [markdown]
# ## **Finetune the pretrained network**
# We can try to improve these results by performing fine tuning. In particular, in this paper we try to fine tune the whole pretrained network by setting `trainable = True` without specifing any layer, but rather than the first trial, we try to perform the early stopping strategy. To do this, again we load the pretrained network to don't overwrite previous results. Our densly connected network builds on the top of the pretrained network is the same we have seen before.

# %%
facenet_tun = load_model('/content/gdrive/MyDrive/progetto/modello/keras-facenet/model/facenet_keras.h5')
facenet_tun.load_weights('/content/gdrive/MyDrive/progetto/modello/keras-facenet/weights/facenet_keras_weights.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
facenet_tun.trainable = True
model_tun = Sequential()
#base model
model_tun.add(L.Input(shape=(160,160,3)))
model_tun.add(facenet_tun)
model_tun.add(L.Flatten())
model_tun.add(L.Dense(128, activation="relu",name="classifier_hidden_tun"))
model_tun.add(L.Dense(7,activation = 'softmax'))

model_tun.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v1 (Functio (None, 128)               22808144
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# classifier_hidden_tun (Dense (None, 128)               16512
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 22,825,559
# Trainable params: 22,796,727
# Non-trainable params: 28,832
# _________________________________________________________________

# %% [markdown]
# Since we have many classes and an image belongs only to a specific class, we use the **sparse categorical crossentropy** as loss function. As optimizer, we use **RMSprop** with a **learning rate** one order of magnitude less than before, because we are performing finetuning, and by using an higher **momentum** than before, equal to 0.7. As we said before, we add also the **early stopping** whereby the training will stop when the chosen performance measure stops improving.

# %%
model_tun.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.RMSprop(lr=1e-6, momentum=0.7),
              metrics=['accuracy'])
callbacks = [
    # early stopping
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3),

    # model checkpoints (save the best model)
    tf.keras.callbacks.ModelCheckpoint(
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        filepath='/content/gdrive/MyDrive/progetto/modello/keras-facenet/model/fine_tuning_nuovo.h5'),
]

# %%
fine_history = model_tun.fit(
      train_dataset,
      epochs=50,
      validation_data=valid_dataset,
      callbacks=callbacks,
      batch_size = BATCH_SIZE
      )
# Out:
# Epoch 1/50
# 90/90 [==============================] - 247s 3s/step - loss: 2.0643 - accuracy: 0.2048 - val_loss: 2.3237 - val_accuracy: 0.0787
# Epoch 2/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.9601 - accuracy: 0.2400 - val_loss: 2.1362 - val_accuracy: 0.1247
# Epoch 3/50
# 90/90 [==============================] - 226s 2s/step - loss: 1.8760 - accuracy: 0.2727 - val_loss: 1.9970 - val_accuracy: 0.1763
# Epoch 4/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.8003 - accuracy: 0.2980 - val_loss: 1.8884 - val_accuracy: 0.2256
# Epoch 5/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.7299 - accuracy: 0.3344 - val_loss: 1.7986 - val_accuracy: 0.2759
# Epoch 6/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.6626 - accuracy: 0.3676 - val_loss: 1.7205 - val_accuracy: 0.3219
# Epoch 7/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.6074 - accuracy: 0.3890 - val_loss: 1.6522 - val_accuracy: 0.3658
# Epoch 8/50
# 90/90 [==============================] - 226s 2s/step - loss: 1.5502 - accuracy: 0.4154 - val_loss: 1.5910 - val_accuracy: 0.4022
# Epoch 9/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.5034 - accuracy: 0.4377 - val_loss: 1.5363 - val_accuracy: 0.4381
# Epoch 10/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.4568 - accuracy: 0.4590 - val_loss: 1.4866 - val_accuracy: 0.4647
# Epoch 11/50
# 90/90 [==============================] - 226s 2s/step - loss: 1.4149 - accuracy: 0.4791 - val_loss: 1.4441 - val_accuracy: 0.4875
# Epoch 12/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.3808 - accuracy: 0.4971 - val_loss: 1.4050 - val_accuracy: 0.5065
# Epoch 13/50
# 90/90 [==============================] - 226s 2s/step - loss: 1.3409 - accuracy: 0.5103 - val_loss: 1.3680 - val_accuracy: 0.5217
# Epoch 14/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.3134 - accuracy: 0.5179 - val_loss: 1.3338 - val_accuracy: 0.5393
# Epoch 15/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.2774 - accuracy: 0.5329 - val_loss: 1.3027 - val_accuracy: 0.5522
# Epoch 16/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.2522 - accuracy: 0.5459 - val_loss: 1.2738 - val_accuracy: 0.5626
# Epoch 17/50
# 90/90 [==============================] - 226s 2s/step - loss: 1.2246 - accuracy: 0.5527 - val_loss: 1.2484 - val_accuracy: 0.5713
# Epoch 18/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.2021 - accuracy: 0.5624 - val_loss: 1.2241 - val_accuracy: 0.5828
# Epoch 19/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.1777 - accuracy: 0.5711 - val_loss: 1.1991 - val_accuracy: 0.5907
# Epoch 20/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.1581 - accuracy: 0.5775 - val_loss: 1.1781 - val_accuracy: 0.6002
# Epoch 21/50
# 90/90 [==============================] - 226s 2s/step - loss: 1.1375 - accuracy: 0.5905 - val_loss: 1.1593 - val_accuracy: 0.6103
# Epoch 22/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.1149 - accuracy: 0.5953 - val_loss: 1.1382 - val_accuracy: 0.6187
# Epoch 23/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.1016 - accuracy: 0.6017 - val_loss: 1.1185 - val_accuracy: 0.6245
# Epoch 24/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.0793 - accuracy: 0.6128 - val_loss: 1.1015 - val_accuracy: 0.6311
# Epoch 25/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.0593 - accuracy: 0.6218 - val_loss: 1.0858 - val_accuracy: 0.6356
# Epoch 26/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.0514 - accuracy: 0.6197 - val_loss: 1.0697 - val_accuracy: 0.6443
# Epoch 27/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.0342 - accuracy: 0.6278 - val_loss: 1.0556 - val_accuracy: 0.6487
# Epoch 28/50
# 90/90 [==============================] - 225s 2s/step - loss: 1.0207 - accuracy: 0.6337 - val_loss: 1.0407 - val_accuracy: 0.6541
# Epoch 29/50
# 90/90 [==============================] - 226s 2s/step - loss: 1.0050 - accuracy: 0.6405 - val_loss: 1.0265 - val_accuracy: 0.6598
# Epoch 30/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.9908 - accuracy: 0.6404 - val_loss: 1.0138 - val_accuracy: 0.6645
# Epoch 31/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.9787 - accuracy: 0.6470 - val_loss: 1.0009 - val_accuracy: 0.6708
# Epoch 32/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.9688 - accuracy: 0.6532 - val_loss: 0.9912 - val_accuracy: 0.6738
# Epoch 33/50
# 90/90 [==============================] - 226s 2s/step - loss: 0.9522 - accuracy: 0.6600 - val_loss: 0.9801 - val_accuracy: 0.6765
# Epoch 34/50
# 90/90 [==============================] - 226s 2s/step - loss: 0.9387 - accuracy: 0.6652 - val_loss: 0.9679 - val_accuracy: 0.6816
# Epoch 35/50
# 90/90 [==============================] - 226s 2s/step - loss: 0.9275 - accuracy: 0.6684 - val_loss: 0.9549 - val_accuracy: 0.6859
# Epoch 36/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.9112 - accuracy: 0.6768 - val_loss: 0.9433 - val_accuracy: 0.6879
# Epoch 37/50
# 90/90 [==============================] - 226s 2s/step - loss: 0.9019 - accuracy: 0.6797 - val_loss: 0.9325 - val_accuracy: 0.6926
# Epoch 38/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.8867 - accuracy: 0.6875 - val_loss: 0.9224 - val_accuracy: 0.6950
# Epoch 39/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.8768 - accuracy: 0.6922 - val_loss: 0.9121 - val_accuracy: 0.6983
# Epoch 40/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.8620 - accuracy: 0.6976 - val_loss: 0.9010 - val_accuracy: 0.7016
# Epoch 41/50
# 90/90 [==============================] - 226s 2s/step - loss: 0.8559 - accuracy: 0.6973 - val_loss: 0.8901 - val_accuracy: 0.7053
# Epoch 42/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.8444 - accuracy: 0.7014 - val_loss: 0.8813 - val_accuracy: 0.7088
# Epoch 43/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.8288 - accuracy: 0.7110 - val_loss: 0.8713 - val_accuracy: 0.7121
# Epoch 44/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.8208 - accuracy: 0.7171 - val_loss: 0.8599 - val_accuracy: 0.7185
# Epoch 45/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.8062 - accuracy: 0.7206 - val_loss: 0.8511 - val_accuracy: 0.7211
# Epoch 46/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.7963 - accuracy: 0.7242 - val_loss: 0.8394 - val_accuracy: 0.7246
# Epoch 47/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.7862 - accuracy: 0.7292 - val_loss: 0.8309 - val_accuracy: 0.7295
# Epoch 48/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.7724 - accuracy: 0.7346 - val_loss: 0.8209 - val_accuracy: 0.7314
# Epoch 49/50
# 90/90 [==============================] - 226s 2s/step - loss: 0.7636 - accuracy: 0.7362 - val_loss: 0.8119 - val_accuracy: 0.7351
# Epoch 50/50
# 90/90 [==============================] - 225s 2s/step - loss: 0.7490 - accuracy: 0.7414 - val_loss: 0.8019 - val_accuracy: 0.7394

# %% [markdown]
# ## **Plot**
# Now, as we can see, we have better performance than before. Then we have an high accuracy either in training (little more than 70%) and in testing (equal to 60%).

# %%
fine_acc = fine_history.history['accuracy']
fine_val_acc = fine_history.history['val_accuracy']
fine_loss = fine_history.history['loss']
fine_val_loss = fine_history.history['val_loss']

epochs = range(len(fine_acc))

plt.plot(epochs, fine_acc, 'r', label='Training acc')
plt.plot(epochs, fine_val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, fine_loss, 'r', label='Training loss')
plt.plot(epochs, fine_val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
test_loss, test_accuracy = model_tun.evaluate(testing_dataset)
print("Test loss", test_loss)
print("Test accuracy",test_accuracy)
# Out:
# 15/15 [==============================] - 11s 661ms/step - loss: 1.0782 - accuracy: 0.6027
# Test loss 1.0781854391098022
# Test accuracy 0.6026748418807983

# %%
#model.save('/content/gdrive/MyDrive/progetto/modello/keras-facenet/model/fine_tuning_with_RMSProp.h5')
#model_tun.save('/content/gdrive/MyDrive/progetto/modello/keras-facenet/model/fine_tuning_all_unfreezed.h5')

# %% [markdown]
# ## **Overall plot**
# Now we can see the results comparison of both the model performed. Again, we can appreciate the improving of the finetuned model.

# %%
# data from training with freezed mobilenet
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

# data from fine-tuning training
ft_acc = fine_history.history['accuracy']
ft_val_acc = fine_history.history['val_accuracy']
ft_loss = fine_history.history['loss']
ft_val_loss = fine_history.history['val_loss']

# create figure
fig, (acc_g,loss_g) = plt.subplots(1,2, figsize=(15,6))

# range for x axis
epochs = range(len(acc))
epochs_1 = range(len(ft_acc))

# plot accuracy curves
acc_g.plot(epochs, acc, color='tab:orange', marker='x', linestyle='-', label='Classifier training', linewidth=1)
acc_g.plot(epochs, val_acc, color='tab:blue', marker='x', linestyle='-', label='Classifier validation', linewidth=1)
acc_g.plot(epochs_1, ft_acc, color='tab:olive', marker='^', linestyle='-', label='Fine-tuning training', linewidth=1)
acc_g.plot(epochs_1, ft_val_acc, color='tab:cyan', marker='^', linestyle='-', label='Fine-tuning validation', linewidth=1)

# plot loss curves
loss_g.plot(epochs, loss, color='tab:orange', marker='x', linestyle='-', label='Classifier training ', linewidth=1)
loss_g.plot(epochs, val_loss, color='tab:blue', marker='x', linestyle='-', label='Classifier validation', linewidth=1)
loss_g.plot(epochs_1, ft_loss, color='tab:olive', marker='^', linestyle='-', label='Fine-tuning training ', linewidth=1)
loss_g.plot(epochs_1, ft_val_loss, color='tab:cyan', marker='^', linestyle='-', label='Fine-tuning validation', linewidth=1)

# accuracy graph style options
acc_g.grid(axis='y', linestyle='--', linewidth=0.5)
acc_g.set_xlabel('Epochs')
acc_g.set_ylabel('Accuracy')
acc_g.set_title('Accuracy', fontdict={'fontsize':18}, pad=20)
acc_g.legend(loc='lower right')

# loss graph style options
loss_g.grid(axis='y', linestyle='--', linewidth=0.5)
loss_g.set_xlabel('Epochs')
loss_g.set_ylabel('Loss')
loss_g.set_title('Loss', fontdict={'fontsize':18}, pad=20)
loss_g.legend(loc='upper right')

# layout adjustment
plt.tight_layout()
